# %%
import requests
import json
from dotenv import load_dotenv
import os
import pandas as pd
import sys
sys.path.append("../")
from functools import reduce
import operator
import geopandas as gpd
import folium
from folium import Choropleth, Circle, Marker, Icon, Map
from folium.plugins import HeatMap, MarkerCluster

# %%
from src.geocode import *
from src.getFromDict import getFromDict
from src.create_marker import *

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# Importamos los token de la página de foursquare

# %%
token1 = os.getenv("token1")
token2 = os.getenv("token2")

# %%
address = "Madrid"

# %%
madrid = geocode(address)

# %%
madrid
# Out:
# {'type': 'Point', 'coordinates': [-3.6793, 40.42955]}

# %%
madrid = {'type': 'Point', 'coordinates': [-3.6793, 40.42955]}

# %%
url_mother = 'https://api.foursquare.com/v2/venues/explore'

# %% [markdown]
# Buscamos los Starbucks en Madrid

# %%
search ="starbucks"

# %%
print(madrid.get("coordinates")[0])
# Out:
# -3.6793

# %%
parametros = { "client_id" : token1,
          "client_secret" : token2,
          "v" : "20180323",
          "ll": f"{madrid.get('coordinates')[1]},{madrid.get('coordinates')[0]}",
          "query": f"{search}",
          "limit" : 100
}

# %%
resp = requests.get (url = url_mother, params = parametros)
data = json.loads(resp.text)

# %%
data.keys()
# Out:
# dict_keys(['meta', 'response'])

# %%
data
# Out:
# {'meta': {'code': 200, 'requestId': '5fb2668366505c5f6f723831'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'suggestedRadius': 1869,
#   'headerLocation': 'Lista',
#   'headerFullLocation': 'Lista, Madrid',
#   'headerLocationGranularity': 'neighborhood',
#   'query': 'starbucks',
#   'totalResults': 46,
#   'suggestedBounds': {'ne': {'lat': 40.50439644164747,
#     'lng': -3.5728318934028294},
#    'sw': {'lat': 40.356793487052315, 'lng': -3.804362238540586}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9a5902f964a520edad35e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. del Conde de Peñalver, 10',
#         'crossStreet': 'C. Hermosilla',
#         'lat': 40.426066801136066,
#         'lng': -3.6756167469058876,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.426066801136066,
#           'lng': -3.6756167469058876}],
#         'distance': 497,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. del Conde de Peñalver, 10 (C. Hermosilla)',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b9a5902f964a520edad35e3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b1e6d91f964a520d81924e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. de Juan Bravo, 16',
#         'crossStreet': 'C. Juan Bravo',
#         'lat': 40.43296760669224,
#         'lng': -3.6832201480865474,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.43296760669224,
#           'lng': -3.6832201480865474}],
#         'distance': 505,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Juan Bravo, 16 (C. Juan Bravo)',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4b1e6d91f964a520d81924e3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc35444920eb71324471d2c',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Serrano, 100',
#         'lat': 40.4335639178076,
#         'lng': -3.6868293595360973,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4335639178076,
#           'lng': -3.6868293595360973}],
#         'distance': 778,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Serrano, 100',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4bc35444920eb71324471d2c-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '598986e1f5e9d717167f751f',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Velázquez, 32',
#         'lat': 40.424974636524,
#         'lng': -3.684107212216363,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.424974636524,
#           'lng': -3.684107212216363}],
#         'distance': 652,
#         'postalCode': '28002',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Velázquez, 32',
#          '28002 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-598986e1f5e9d717167f751f-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4af3208ef964a520f1ea21e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Génova, 27',
#         'lat': 40.425760357264515,
#         'lng': -3.691781759262085,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.425760357264515,
#           'lng': -3.691781759262085}],
#         'distance': 1138,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Génova, 27',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4af3208ef964a520f1ea21e3-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bc0c7fe4cdfc9b6d1779321',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. de Velázquez, 136',
#         'crossStreet': 'C. López De Hoyos',
#         'lat': 40.4394314443529,
#         'lng': -3.6826531171468173,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.4394314443529,
#           'lng': -3.6826531171468173}],
#         'distance': 1136,
#         'postalCode': '28006',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Velázquez, 136 (C. López De Hoyos)',
#          '28006 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4bc0c7fe4cdfc9b6d1779321-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51e50f52498e52c64085b972',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. María de Molina, 41',
#         'lat': 40.420450975922165,
#         'lng': -3.6796733064135796,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.420450975922165,
#           'lng': -3.6796733064135796}],
#         'distance': 1013,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. María de Molina, 41',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-51e50f52498e52c64085b972-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59cdf2c30fe7a025a229a007',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Pl. de Pedro Zerolo, 12',
#         'lat': 40.42075183549848,
#         'lng': -3.6993145297210788,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42075183549848,
#           'lng': -3.6993145297210788}],
#         'distance': 1958,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Pedro Zerolo, 12',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-59cdf2c30fe7a025a229a007-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b19810ef964a5208bde23e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Alcalá, 21',
#         'lat': 40.418038185194774,
#         'lng': -3.699371513099982,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.418038185194774,
#           'lng': -3.699371513099982}],
#         'distance': 2129,
#         'postalCode': '28014',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Alcalá, 21',
#          '28014 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b19810ef964a5208bde23e3-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b66c179f964a520c6292be3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Gran Vía, 30',
#         'lat': 40.42014039388448,
#         'lng': -3.702886033408268,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42014039388448,
#           'lng': -3.702886033408268}],
#         'distance': 2256,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gran Vía, 30',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b66c179f964a520c6292be3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b73c42ff964a52026bb2de3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Pl. Cánovas del Castillo, 5',
#         'lat': 40.41532327347708,
#         'lng': -3.6949486687744146,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41532327347708,
#           'lng': -3.6949486687744146}],
#         'distance': 2065,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Cánovas del Castillo, 5',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b73c42ff964a52026bb2de3-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5644bebe498eda8d0037f00c',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'P. de la Castellana, 75',
#         'crossStreet': 'Paseo de la Castellana, 75',
#         'lat': 40.44748872381242,
#         'lng': -3.6930934929855574,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44748872381242,
#           'lng': -3.6930934929855574}],
#         'distance': 2313,
#         'postalCode': '28003',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['P. de la Castellana, 75 (Paseo de la Castellana, 75)',
#          '28003 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5644bebe498eda8d0037f00c-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bcc2db8cc8cd13aec78c0cf',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Fuencarral, 43',
#         'lat': 40.423112989750564,
#         'lng': -3.700798408458431,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.423112989750564,
#           'lng': -3.700798408458431}],
#         'distance': 1957,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Fuencarral, 43',
#          '28004 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4bcc2db8cc8cd13aec78c0cf-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e68691752b128a09eb7f69e',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Oquendo, 18',
#         'lat': 40.440273,
#         'lng': -3.682125,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.440273,
#           'lng': -3.682125}],
#         'distance': 1217,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Oquendo, 18', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'referralId': 'e-0-4e68691752b128a09eb7f69e-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '593ac75159fe5c3bbdd96471',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': '27 C. de Preciados',
#         'lat': 40.419667845686355,
#         'lng': -3.7061354223688325,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.419667845686355,
#           'lng': -3.7061354223688325}],
#         'distance': 2526,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['27 C. de Preciados',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-593ac75159fe5c3bbdd96471-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59ef8c45356b49246b403fbc',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Gta. de Quevedo, 9',
#         'lat': 40.433353,
#         'lng': -3.703958,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.433353,
#           'lng': -3.703958}],
#         'distance': 2131,
#         'postalCode': '28015',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Gta. de Quevedo, 9',
#          '28015 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-59ef8c45356b49246b403fbc-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5614de80498ec698c58fbd78',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Paseo de la Castellana, 75',
#         'lat': 40.44677599194058,
#         'lng': -3.6918291111629657,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44677599194058,
#           'lng': -3.6918291111629657}],
#         'distance': 2191,
#         'postalCode': '28003',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Paseo de la Castellana, 75',
#          '28003 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5614de80498ec698c58fbd78-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b52f5dff964a520688b27e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Orense 6',
#         'lat': 40.44772869759542,
#         'lng': -3.6951754717412046,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44772869759542,
#           'lng': -3.6951754717412046}],
#         'distance': 2429,
#         'postalCode': '28020',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Orense 6', '28020 Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b52f5dff964a520688b27e3-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9b5750f964a520790136e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Arenal, 14',
#         'lat': 40.41719516711848,
#         'lng': -3.706118548830636,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41719516711848,
#           'lng': -3.706118548830636}],
#         'distance': 2656,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Arenal, 14',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b9b5750f964a520790136e3-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9a010ff964a520b49a35e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Doctor Drumen, 4',
#         'crossStreet': 'Museo Reina Sofia',
#         'lat': 40.40885214578761,
#         'lng': -3.693236539287397,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.40885214578761,
#           'lng': -3.693236539287397}],
#         'distance': 2589,
#         'postalCode': '28012',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Doctor Drumen, 4 (Museo Reina Sofia)',
#          '28012 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b9a010ff964a520b49a35e3-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b837d7cf964a520bd0731e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Gran Vía, 73',
#         'crossStreet': 'Pl. de España',
#         'lat': 40.423319643246955,
#         'lng': -3.710882844657412,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.423319643246955,
#           'lng': -3.710882844657412}],
#         'distance': 2764,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gran Vía, 73 (Pl. de España)',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b837d7cf964a520bd0731e3-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5d2b5bda53331f002344bbad',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Calle de la Montera 8',
#         'lat': 40.417539,
#         'lng': -3.702775,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.417539,
#           'lng': -3.702775}],
#         'distance': 2396,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Calle de la Montera 8',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5d2b5bda53331f002344bbad-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b60acc6f964a5207af329e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Gran Vía, 58',
#         'lat': 40.421751918201934,
#         'lng': -3.7083782102926905,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421751918201934,
#           'lng': -3.7083782102926905}],
#         'distance': 2612,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Gran Vía, 58',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b60acc6f964a5207af329e3-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b6d7fddf964a52088782ce3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Princesa, 40',
#         'crossStreet': 'C. de Serrano Jover, 1',
#         'lat': 40.42906874005007,
#         'lng': -3.7150786671568476,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.42906874005007,
#           'lng': -3.7150786671568476}],
#         'distance': 3032,
#         'postalCode': '28008',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Princesa, 40 (C. de Serrano Jover, 1)',
#          '28008 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b6d7fddf964a52088782ce3-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b463590a42362002c81e333',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Pza. de Isabel II s/n',
#         'lat': 40.418054,
#         'lng': -3.710009,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.418054,
#           'lng': -3.710009}],
#         'distance': 2900,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pza. de Isabel II s/n',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5b463590a42362002c81e333-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '519681f9498e614af99d523a',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'El Corte Inglés',
#         'crossStreet': 'C. Preciados, 3',
#         'lat': 40.41748942152583,
#         'lng': -3.70466514037747,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.41748942152583,
#           'lng': -3.70466514037747}],
#         'distance': 2534,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['El Corte Inglés (C. Preciados, 3)',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-519681f9498e614af99d523a-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5c893a6f234724002cc94594',
#        'name': 'Starbucks Palace',
#        'contact': {},
#        'location': {'address': 'Pl. Cánovas del Castillo, 5',
#         'lat': 40.414995,
#         'lng': -3.695058,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.414995,
#           'lng': -3.695058}],
#         'distance': 2099,
#         'postalCode': '28005',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. Cánovas del Castillo, 5',
#          '28005 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d128941735',
#          'name': 'Cafeteria',
#          'pluralName': 'Cafeterias',
#          'shortName': 'Cafeteria',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5c893a6f234724002cc94594-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5cb0c67b4aa3f8002ce16016',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'lat': 40.421095,
#         'lng': -3.70256,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.421095,
#           'lng': -3.70256}],
#         'distance': 2184,
#         'postalCode': '28004',
#         'cc': 'ES',
#         'city': 'Madri',
#         'state': 'Madri',
#         'country': 'España',
#         'formattedAddress': ['28004 Madri Madri', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5cb0c67b4aa3f8002ce16016-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5b20bd0c75dcb7002c0a7f19',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Pl. de Isabel II, 4',
#         'lat': 40.418106483857194,
#         'lng': -3.709606077515513,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.418106483857194,
#           'lng': -3.709606077515513}],
#         'distance': 2866,
#         'postalCode': '28013',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Pl. de Isabel II, 4',
#          '28013 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5b20bd0c75dcb7002c0a7f19-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a18799b780eee2e53b2d96a',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. de Orense, 79',
#         'crossStreet': 'C. Sor Ángela de la Cruz',
#         'lat': 40.45957,
#         'lng': -3.6943874,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.45957,
#           'lng': -3.6943874}],
#         'distance': 3577,
#         'postalCode': '28020',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Orense, 79 (C. Sor Ángela de la Cruz)',
#          '28020 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5a18799b780eee2e53b2d96a-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50068e83e4b0ae5996a1b015',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Serrano, 41',
#         'lat': 40.403120577140534,
#         'lng': -3.687687685586035,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.403120577140534,
#           'lng': -3.687687685586035}],
#         'distance': 3026,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Serrano, 41', 'Madrid Madrid', 'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
# ...
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '555194a6498eedc18f4fdabc',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'P. de la Castellana, 278',
#         'lat': 40.47592318265012,
#         'lng': -3.6866703618636074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.47592318265012,
#           'lng': -3.6866703618636074}],
#         'distance': 5199,
#         'postalCode': '28046',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['P. de la Castellana, 278',
#          '28046 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-555194a6498eedc18f4fdabc-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b673c58f964a520fd422be3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. de Silvano, 79',
#         'crossStreet': 'C. Silvano, 77',
#         'lat': 40.46282268242124,
#         'lng': -3.636758032267253,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.46282268242124,
#           'lng': -3.636758032267253}],
#         'distance': 5167,
#         'postalCode': '28043',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. de Silvano, 79 (C. Silvano, 77)',
#          '28043 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b673c58f964a520fd422be3-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b7137e0f964a520f23c2de3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Av. de Monforte de Lemos, 36',
#         'lat': 40.47963598026618,
#         'lng': -3.707357285899872,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.47963598026618,
#           'lng': -3.707357285899872}],
#         'distance': 6060,
#         'postalCode': '28029',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Av. de Monforte de Lemos, 36',
#          '28029 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4b7137e0f964a520f23c2de3-38'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a3bcf2fb8fd9d5a751dbbcd',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Margarita de Parma, 1',
#         'crossStreet': 'C. Margarita de Parma, 1',
#         'lat': 40.49768721643861,
#         'lng': -3.660368141302403,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.49768721643861,
#           'lng': -3.660368141302403}],
#         'distance': 7752,
#         'postalCode': '28050',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Margarita de Parma, 1 (C. Margarita de Parma, 1)',
#          '28050 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-5a3bcf2fb8fd9d5a751dbbcd-39'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d0a5d318ea0a1439bbce573',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Aracne, 3',
#         'crossStreet': 'C. Aracne, 3',
#         'lat': 40.44638591027995,
#         'lng': -3.587592789104539,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.44638591027995,
#           'lng': -3.587592789104539}],
#         'distance': 7992,
#         'postalCode': '28022',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Aracne, 3 (C. Aracne, 3)',
#          '28022 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4d0a5d318ea0a1439bbce573-40'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '567a5f5d498eaee50e4484f2',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Avenida de la Hispanidad 28042, Madrid, Spain',
#         'lat': 40.455039,
#         'lng': -3.583356,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.455039,
#           'lng': -3.583356}],
#         'distance': 8609,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Avenida de la Hispanidad 28042, Madrid, Spain',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-567a5f5d498eaee50e4484f2-41'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c2f6968452620a1556e1d0f',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Calderilla, 1',
#         'crossStreet': 'C. de la Calderilla, 1',
#         'lat': 40.36350271226119,
#         'lng': -3.7365511407333716,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.36350271226119,
#           'lng': -3.7365511407333716}],
#         'distance': 8809,
#         'postalCode': '28054',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Calderilla, 1 (C. de la Calderilla, 1)',
#          '28054 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4c2f6968452620a1556e1d0f-42'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '580ce0ef38fa626ebe30ad00',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Av. de Europa, 11',
#         'lat': 40.43816816158585,
#         'lng': -3.793838131943415,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.43816816158585,
#           'lng': -3.793838131943415}],
#         'distance': 9752,
#         'postalCode': '28224',
#         'cc': 'ES',
#         'city': 'Pozuelo de Alarcón',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Av. de Europa, 11',
#          '28224 Pozuelo de Alarcón Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-580ce0ef38fa626ebe30ad00-43'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba3b2f9f964a520c95538e3',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'C. Adolfo Bioy Casares, 2',
#         'crossStreet': 'C. Adolfo Bioy Casares, 2',
#         'lat': 40.36878210729123,
#         'lng': -3.5969286239354488,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.36878210729123,
#           'lng': -3.5969286239354488}],
#         'distance': 9722,
#         'postalCode': '28051',
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['C. Adolfo Bioy Casares, 2 (C. Adolfo Bioy Casares, 2)',
#          '28051 Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': True,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-4ba3b2f9f964a520c95538e3-44'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '534e8760498ef7005b8d8478',
#        'name': 'Starbucks',
#        'contact': {},
#        'location': {'address': 'Adolfo Suárez Madrid-Barajas Airport (MAD)',
#         'crossStreet': 'Terminal 4',
#         'lat': 40.49024076241017,
#         'lng': -3.5910167013925776,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 40.49024076241017,
#           'lng': -3.5910167013925776}],
#         'distance': 10077,
#         'cc': 'ES',
#         'city': 'Madrid',
#         'state': 'Madrid',
#         'country': 'España',
#         'formattedAddress': ['Adolfo Suárez Madrid-Barajas Airport (MAD) (Terminal 4)',
#          'Madrid Madrid',
#          'España']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'verified': False,
#        'stats': {'tipCount': 0,
#         'usersCount': 0,
#         'checkinsCount': 0,
#         'visitsCount': 0},
#        'beenHere': {'count': 0,
#         'lastCheckinExpiredAt': 0,
#         'marked': False,
#         'unconfirmedCount': 0},
#        'photos': {'count': 0, 'groups': []},
#        'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#       'flags': {'outsideRadius': True},
#       'referralId': 'e-0-534e8760498ef7005b8d8478-45'}]}]}}

# %%
decoding_data = data.get("response")
decoding_data
# Out:
# {'suggestedFilters': {'header': 'Tap to show:',
#   'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#  'suggestedRadius': 1869,
#  'headerLocation': 'Lista',
#  'headerFullLocation': 'Lista, Madrid',
#  'headerLocationGranularity': 'neighborhood',
#  'query': 'starbucks',
#  'totalResults': 46,
#  'suggestedBounds': {'ne': {'lat': 40.50439644164747,
#    'lng': -3.5728318934028294},
#   'sw': {'lat': 40.356793487052315, 'lng': -3.804362238540586}},
#  'groups': [{'type': 'Recommended Places',
#    'name': 'recommended',
#    'items': [{'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b9a5902f964a520edad35e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. del Conde de Peñalver, 10',
#        'crossStreet': 'C. Hermosilla',
#        'lat': 40.426066801136066,
#        'lng': -3.6756167469058876,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.426066801136066,
#          'lng': -3.6756167469058876}],
#        'distance': 497,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. del Conde de Peñalver, 10 (C. Hermosilla)',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-4b9a5902f964a520edad35e3-0'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b1e6d91f964a520d81924e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. de Juan Bravo, 16',
#        'crossStreet': 'C. Juan Bravo',
#        'lat': 40.43296760669224,
#        'lng': -3.6832201480865474,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43296760669224,
#          'lng': -3.6832201480865474}],
#        'distance': 505,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. de Juan Bravo, 16 (C. Juan Bravo)',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-4b1e6d91f964a520d81924e3-1'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4bc35444920eb71324471d2c',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Serrano, 100',
#        'lat': 40.4335639178076,
#        'lng': -3.6868293595360973,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4335639178076,
#          'lng': -3.6868293595360973}],
#        'distance': 778,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Serrano, 100',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-4bc35444920eb71324471d2c-2'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '598986e1f5e9d717167f751f',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Velázquez, 32',
#        'lat': 40.424974636524,
#        'lng': -3.684107212216363,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.424974636524,
#          'lng': -3.684107212216363}],
#        'distance': 652,
#        'postalCode': '28002',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Velázquez, 32',
#         '28002 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-598986e1f5e9d717167f751f-3'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4af3208ef964a520f1ea21e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Génova, 27',
#        'lat': 40.425760357264515,
#        'lng': -3.691781759262085,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.425760357264515,
#          'lng': -3.691781759262085}],
#        'distance': 1138,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Génova, 27', '28004 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-4af3208ef964a520f1ea21e3-4'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4bc0c7fe4cdfc9b6d1779321',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. de Velázquez, 136',
#        'crossStreet': 'C. López De Hoyos',
#        'lat': 40.4394314443529,
#        'lng': -3.6826531171468173,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4394314443529,
#          'lng': -3.6826531171468173}],
#        'distance': 1136,
#        'postalCode': '28006',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. de Velázquez, 136 (C. López De Hoyos)',
#         '28006 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-4bc0c7fe4cdfc9b6d1779321-5'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '51e50f52498e52c64085b972',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. María de Molina, 41',
#        'lat': 40.420450975922165,
#        'lng': -3.6796733064135796,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.420450975922165,
#          'lng': -3.6796733064135796}],
#        'distance': 1013,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. María de Molina, 41',
#         'Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-51e50f52498e52c64085b972-6'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59cdf2c30fe7a025a229a007',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Pl. de Pedro Zerolo, 12',
#        'lat': 40.42075183549848,
#        'lng': -3.6993145297210788,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42075183549848,
#          'lng': -3.6993145297210788}],
#        'distance': 1958,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Pl. de Pedro Zerolo, 12',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-59cdf2c30fe7a025a229a007-7'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b19810ef964a5208bde23e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Alcalá, 21',
#        'lat': 40.418038185194774,
#        'lng': -3.699371513099982,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.418038185194774,
#          'lng': -3.699371513099982}],
#        'distance': 2129,
#        'postalCode': '28014',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Alcalá, 21', '28014 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b19810ef964a5208bde23e3-8'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b66c179f964a520c6292be3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Gran Vía, 30',
#        'lat': 40.42014039388448,
#        'lng': -3.702886033408268,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42014039388448,
#          'lng': -3.702886033408268}],
#        'distance': 2256,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Gran Vía, 30',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b66c179f964a520c6292be3-9'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b73c42ff964a52026bb2de3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Pl. Cánovas del Castillo, 5',
#        'lat': 40.41532327347708,
#        'lng': -3.6949486687744146,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.41532327347708,
#          'lng': -3.6949486687744146}],
#        'distance': 2065,
#        'postalCode': '28005',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Pl. Cánovas del Castillo, 5',
#         '28005 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b73c42ff964a52026bb2de3-10'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5644bebe498eda8d0037f00c',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'P. de la Castellana, 75',
#        'crossStreet': 'Paseo de la Castellana, 75',
#        'lat': 40.44748872381242,
#        'lng': -3.6930934929855574,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44748872381242,
#          'lng': -3.6930934929855574}],
#        'distance': 2313,
#        'postalCode': '28003',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['P. de la Castellana, 75 (Paseo de la Castellana, 75)',
#         '28003 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5644bebe498eda8d0037f00c-11'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4bcc2db8cc8cd13aec78c0cf',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Fuencarral, 43',
#        'lat': 40.423112989750564,
#        'lng': -3.700798408458431,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.423112989750564,
#          'lng': -3.700798408458431}],
#        'distance': 1957,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Fuencarral, 43',
#         '28004 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4bcc2db8cc8cd13aec78c0cf-12'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4e68691752b128a09eb7f69e',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Oquendo, 18',
#        'lat': 40.440273,
#        'lng': -3.682125,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.440273,
#          'lng': -3.682125}],
#        'distance': 1217,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Oquendo, 18', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'referralId': 'e-0-4e68691752b128a09eb7f69e-13'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '593ac75159fe5c3bbdd96471',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': '27 C. de Preciados',
#        'lat': 40.419667845686355,
#        'lng': -3.7061354223688325,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.419667845686355,
#          'lng': -3.7061354223688325}],
#        'distance': 2526,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['27 C. de Preciados',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-593ac75159fe5c3bbdd96471-14'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '59ef8c45356b49246b403fbc',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Gta. de Quevedo, 9',
#        'lat': 40.433353,
#        'lng': -3.703958,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.433353,
#          'lng': -3.703958}],
#        'distance': 2131,
#        'postalCode': '28015',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Gta. de Quevedo, 9',
#         '28015 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-59ef8c45356b49246b403fbc-15'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5614de80498ec698c58fbd78',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Paseo de la Castellana, 75',
#        'lat': 40.44677599194058,
#        'lng': -3.6918291111629657,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44677599194058,
#          'lng': -3.6918291111629657}],
#        'distance': 2191,
#        'postalCode': '28003',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Paseo de la Castellana, 75',
#         '28003 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5614de80498ec698c58fbd78-16'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b52f5dff964a520688b27e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Orense 6',
#        'lat': 40.44772869759542,
#        'lng': -3.6951754717412046,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44772869759542,
#          'lng': -3.6951754717412046}],
#        'distance': 2429,
#        'postalCode': '28020',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Orense 6', '28020 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b52f5dff964a520688b27e3-17'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b9b5750f964a520790136e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Arenal, 14',
#        'lat': 40.41719516711848,
#        'lng': -3.706118548830636,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.41719516711848,
#          'lng': -3.706118548830636}],
#        'distance': 2656,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Arenal, 14', '28013 Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b9b5750f964a520790136e3-18'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b9a010ff964a520b49a35e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Doctor Drumen, 4',
#        'crossStreet': 'Museo Reina Sofia',
#        'lat': 40.40885214578761,
#        'lng': -3.693236539287397,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.40885214578761,
#          'lng': -3.693236539287397}],
#        'distance': 2589,
#        'postalCode': '28012',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Doctor Drumen, 4 (Museo Reina Sofia)',
#         '28012 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b9a010ff964a520b49a35e3-19'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b837d7cf964a520bd0731e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Gran Vía, 73',
#        'crossStreet': 'Pl. de España',
#        'lat': 40.423319643246955,
#        'lng': -3.710882844657412,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.423319643246955,
#          'lng': -3.710882844657412}],
#        'distance': 2764,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Gran Vía, 73 (Pl. de España)',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b837d7cf964a520bd0731e3-20'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5d2b5bda53331f002344bbad',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Calle de la Montera 8',
#        'lat': 40.417539,
#        'lng': -3.702775,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.417539,
#          'lng': -3.702775}],
#        'distance': 2396,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Calle de la Montera 8',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5d2b5bda53331f002344bbad-21'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b60acc6f964a5207af329e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Gran Vía, 58',
#        'lat': 40.421751918201934,
#        'lng': -3.7083782102926905,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.421751918201934,
#          'lng': -3.7083782102926905}],
#        'distance': 2612,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Gran Vía, 58',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b60acc6f964a5207af329e3-22'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b6d7fddf964a52088782ce3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Princesa, 40',
#        'crossStreet': 'C. de Serrano Jover, 1',
#        'lat': 40.42906874005007,
#        'lng': -3.7150786671568476,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.42906874005007,
#          'lng': -3.7150786671568476}],
#        'distance': 3032,
#        'postalCode': '28008',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Princesa, 40 (C. de Serrano Jover, 1)',
#         '28008 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b6d7fddf964a52088782ce3-23'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5b463590a42362002c81e333',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Pza. de Isabel II s/n',
#        'lat': 40.418054,
#        'lng': -3.710009,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.418054,
#          'lng': -3.710009}],
#        'distance': 2900,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Pza. de Isabel II s/n',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5b463590a42362002c81e333-24'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '519681f9498e614af99d523a',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'El Corte Inglés',
#        'crossStreet': 'C. Preciados, 3',
#        'lat': 40.41748942152583,
#        'lng': -3.70466514037747,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.41748942152583,
#          'lng': -3.70466514037747}],
#        'distance': 2534,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['El Corte Inglés (C. Preciados, 3)',
#         'Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-519681f9498e614af99d523a-25'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5c893a6f234724002cc94594',
#       'name': 'Starbucks Palace',
#       'contact': {},
#       'location': {'address': 'Pl. Cánovas del Castillo, 5',
#        'lat': 40.414995,
#        'lng': -3.695058,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.414995,
#          'lng': -3.695058}],
#        'distance': 2099,
#        'postalCode': '28005',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Pl. Cánovas del Castillo, 5',
#         '28005 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d128941735',
#         'name': 'Cafeteria',
#         'pluralName': 'Cafeterias',
#         'shortName': 'Cafeteria',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/education/cafeteria_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5c893a6f234724002cc94594-26'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5cb0c67b4aa3f8002ce16016',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'lat': 40.421095,
#        'lng': -3.70256,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.421095,
#          'lng': -3.70256}],
#        'distance': 2184,
#        'postalCode': '28004',
#        'cc': 'ES',
#        'city': 'Madri',
#        'state': 'Madri',
#        'country': 'España',
#        'formattedAddress': ['28004 Madri Madri', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5cb0c67b4aa3f8002ce16016-27'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5b20bd0c75dcb7002c0a7f19',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Pl. de Isabel II, 4',
#        'lat': 40.418106483857194,
#        'lng': -3.709606077515513,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.418106483857194,
#          'lng': -3.709606077515513}],
#        'distance': 2866,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Pl. de Isabel II, 4',
#         '28013 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5b20bd0c75dcb7002c0a7f19-28'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5a18799b780eee2e53b2d96a',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. de Orense, 79',
#        'crossStreet': 'C. Sor Ángela de la Cruz',
#        'lat': 40.45957,
#        'lng': -3.6943874,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.45957,
#          'lng': -3.6943874}],
#        'distance': 3577,
#        'postalCode': '28020',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. de Orense, 79 (C. Sor Ángela de la Cruz)',
#         '28020 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5a18799b780eee2e53b2d96a-29'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '50068e83e4b0ae5996a1b015',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Serrano, 41',
#        'lat': 40.403120577140534,
#        'lng': -3.687687685586035,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.403120577140534,
#          'lng': -3.687687685586035}],
#        'distance': 3026,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Serrano, 41', 'Madrid Madrid', 'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-50068e83e4b0ae5996a1b015-30'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5bec46aa898bdc691bbc6f9b',
#       'name': 'Starbucks ECI Preciados',
#       'contact': {},
#       'location': {'address': 'C. de Preciados, 3',
#        'crossStreet': 'C. de Preciados, 3',
#        'lat': 40.4174674,
#        'lng': -3.7043957,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.4174674,
#          'lng': -3.7043957}],
#        'distance': 2516,
#        'postalCode': '28013',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. de Preciados, 3 (C. de Preciados, 3)',
#         '28013 Madrid Madrid',
# ...
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-59ea4524ccad6b7e88d32a86-35'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '555194a6498eedc18f4fdabc',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'P. de la Castellana, 278',
#        'lat': 40.47592318265012,
#        'lng': -3.6866703618636074,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.47592318265012,
#          'lng': -3.6866703618636074}],
#        'distance': 5199,
#        'postalCode': '28046',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['P. de la Castellana, 278',
#         '28046 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-555194a6498eedc18f4fdabc-36'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b673c58f964a520fd422be3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. de Silvano, 79',
#        'crossStreet': 'C. Silvano, 77',
#        'lat': 40.46282268242124,
#        'lng': -3.636758032267253,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.46282268242124,
#          'lng': -3.636758032267253}],
#        'distance': 5167,
#        'postalCode': '28043',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. de Silvano, 79 (C. Silvano, 77)',
#         '28043 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b673c58f964a520fd422be3-37'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4b7137e0f964a520f23c2de3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Av. de Monforte de Lemos, 36',
#        'lat': 40.47963598026618,
#        'lng': -3.707357285899872,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.47963598026618,
#          'lng': -3.707357285899872}],
#        'distance': 6060,
#        'postalCode': '28029',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Av. de Monforte de Lemos, 36',
#         '28029 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4b7137e0f964a520f23c2de3-38'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '5a3bcf2fb8fd9d5a751dbbcd',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Margarita de Parma, 1',
#        'crossStreet': 'C. Margarita de Parma, 1',
#        'lat': 40.49768721643861,
#        'lng': -3.660368141302403,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.49768721643861,
#          'lng': -3.660368141302403}],
#        'distance': 7752,
#        'postalCode': '28050',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Margarita de Parma, 1 (C. Margarita de Parma, 1)',
#         '28050 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-5a3bcf2fb8fd9d5a751dbbcd-39'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4d0a5d318ea0a1439bbce573',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Aracne, 3',
#        'crossStreet': 'C. Aracne, 3',
#        'lat': 40.44638591027995,
#        'lng': -3.587592789104539,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.44638591027995,
#          'lng': -3.587592789104539}],
#        'distance': 7992,
#        'postalCode': '28022',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Aracne, 3 (C. Aracne, 3)',
#         '28022 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4d0a5d318ea0a1439bbce573-40'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '567a5f5d498eaee50e4484f2',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Avenida de la Hispanidad 28042, Madrid, Spain',
#        'lat': 40.455039,
#        'lng': -3.583356,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.455039,
#          'lng': -3.583356}],
#        'distance': 8609,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Avenida de la Hispanidad 28042, Madrid, Spain',
#         'Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-567a5f5d498eaee50e4484f2-41'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4c2f6968452620a1556e1d0f',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Calderilla, 1',
#        'crossStreet': 'C. de la Calderilla, 1',
#        'lat': 40.36350271226119,
#        'lng': -3.7365511407333716,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.36350271226119,
#          'lng': -3.7365511407333716}],
#        'distance': 8809,
#        'postalCode': '28054',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Calderilla, 1 (C. de la Calderilla, 1)',
#         '28054 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4c2f6968452620a1556e1d0f-42'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '580ce0ef38fa626ebe30ad00',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Av. de Europa, 11',
#        'lat': 40.43816816158585,
#        'lng': -3.793838131943415,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.43816816158585,
#          'lng': -3.793838131943415}],
#        'distance': 9752,
#        'postalCode': '28224',
#        'cc': 'ES',
#        'city': 'Pozuelo de Alarcón',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Av. de Europa, 11',
#         '28224 Pozuelo de Alarcón Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-580ce0ef38fa626ebe30ad00-43'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '4ba3b2f9f964a520c95538e3',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'C. Adolfo Bioy Casares, 2',
#        'crossStreet': 'C. Adolfo Bioy Casares, 2',
#        'lat': 40.36878210729123,
#        'lng': -3.5969286239354488,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.36878210729123,
#          'lng': -3.5969286239354488}],
#        'distance': 9722,
#        'postalCode': '28051',
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['C. Adolfo Bioy Casares, 2 (C. Adolfo Bioy Casares, 2)',
#         '28051 Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': True,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-4ba3b2f9f964a520c95538e3-44'},
#     {'reasons': {'count': 0,
#       'items': [{'summary': 'This spot is popular',
#         'type': 'general',
#         'reasonName': 'globalInteractionReason'}]},
#      'venue': {'id': '534e8760498ef7005b8d8478',
#       'name': 'Starbucks',
#       'contact': {},
#       'location': {'address': 'Adolfo Suárez Madrid-Barajas Airport (MAD)',
#        'crossStreet': 'Terminal 4',
#        'lat': 40.49024076241017,
#        'lng': -3.5910167013925776,
#        'labeledLatLngs': [{'label': 'display',
#          'lat': 40.49024076241017,
#          'lng': -3.5910167013925776}],
#        'distance': 10077,
#        'cc': 'ES',
#        'city': 'Madrid',
#        'state': 'Madrid',
#        'country': 'España',
#        'formattedAddress': ['Adolfo Suárez Madrid-Barajas Airport (MAD) (Terminal 4)',
#         'Madrid Madrid',
#         'España']},
#       'categories': [{'id': '4bf58dd8d48988d1e0931735',
#         'name': 'Coffee Shop',
#         'pluralName': 'Coffee Shops',
#         'shortName': 'Coffee Shop',
#         'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#          'suffix': '.png'},
#         'primary': True}],
#       'verified': False,
#       'stats': {'tipCount': 0,
#        'usersCount': 0,
#        'checkinsCount': 0,
#        'visitsCount': 0},
#       'beenHere': {'count': 0,
#        'lastCheckinExpiredAt': 0,
#        'marked': False,
#        'unconfirmedCount': 0},
#       'photos': {'count': 0, 'groups': []},
#       'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#      'flags': {'outsideRadius': True},
#      'referralId': 'e-0-534e8760498ef7005b8d8478-45'}]}]}

# %%
decoded = decoding_data.get("groups")
type(decoded)
# Out:
# list

# %%
type(decoded[0])
# Out:
# dict

# %%
for k,v in decoded[0].items():
    print(k,v,"\n")
# Out:
# type Recommended Places
#
# name recommended
#
# items [{'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b9a5902f964a520edad35e3', 'name': 'Starbucks', 'contact': {}, 'location': {'address': 'C. del Conde de Peñalver, 10', 'crossStreet': 'C. Hermosilla', 'lat': 40.426066801136066, 'lng': -3.6756167469058876, 'labeledLatLngs': [{'label': 'display', 'lat': 40.426066801136066, 'lng': -3.6756167469058876}], 'distance': 497, 'postalCode': '28006', 'cc': 'ES', 'city': 'Madrid', 'state': 'Madrid', 'country': 'España', 'formattedAddress': ['C. del Conde de Peñalver, 10 (C. Hermosilla)', '28006 Madrid Madrid', 'España']}, 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 0, 'usersCount': 0, 'checkinsCount': 0, 'visitsCount': 0}, 'beenHere': {'count': 0, 'lastCheckinExpiredAt': 0, 'marked': False, 'unconfirmedCount': 0}, 'photos': {'count': 0, 'groups': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}, 'referralId': 'e-0-4b9a5902f964a520edad35e3-0'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4b1e6d91f964a520d81924e3', 'name': 'Starbucks', 'contact': {}, 'location': {'address': 'C. de Juan Bravo, 16', 'crossStreet': 'C. Juan Bravo', 'lat': 40.43296760669224, 'lng': -3.6832201480865474, 'labeledLatLngs': [{'label': 'display', 'lat': 40.43296760669224, 'lng': -3.6832201480865474}], 'distance': 505, 'postalCode': '28006', 'cc': 'ES', 'city': 'Madrid', 'state': 'Madrid', 'country': 'España', 'formattedAddress': ['C. de Juan Bravo, 16 (C. Juan Bravo)', '28006 Madrid Madrid', 'España']}, 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 0, 'usersCount': 0, 'checkinsCount': 0, 'visitsCount': 0}, 'beenHere': {'count': 0, 'lastCheckinExpiredAt': 0, 'marked': False, 'unconfirmedCount': 0}, 'photos': {'count': 0, 'groups': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}, 'referralId': 'e-0-4b1e6d91f964a520d81924e3-1'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '4bc35444920eb71324471d2c', 'name': 'Starbucks', 'contact': {}, 'location': {'address': 'C. Serrano, 100', 'lat': 40.4335639178076, 'lng': -3.6868293595360973, 'labeledLatLngs': [{'label': 'display', 'lat': 40.4335639178076, 'lng': -3.6868293595360973}], 'distance': 778, 'postalCode': '28006', 'cc': 'ES', 'city': 'Madrid', 'state': 'Madrid', 'country': 'España', 'formattedAddress': ['C. Serrano, 100', '28006 Madrid Madrid', 'España']}, 'categories': [{'id': '4bf58dd8d48988d1e0931735', 'name': 'Coffee Shop', 'pluralName': 'Coffee Shops', 'shortName': 'Coffee Shop', 'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_', 'suffix': '.png'}, 'primary': True}], 'verified': True, 'stats': {'tipCount': 0, 'usersCount': 0, 'checkinsCount': 0, 'visitsCount': 0}, 'beenHere': {'count': 0, 'lastCheckinExpiredAt': 0, 'marked': False, 'unconfirmedCount': 0}, 'photos': {'count': 0, 'groups': []}, 'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}}, 'referralId': 'e-0-4bc35444920eb71324471d2c-2'}, {'reasons': {'count': 0, 'items': [{'summary': 'This spot is popular', 'type': 'general', 'reasonName': 'globalInteractionReason'}]}, 'venue': {'id': '598986e1f5e9d717167f751f', 'name': 'Starbucks', 'contact': {}, 'location': {'address': 'C. Velázquez, 32', 'lat': 40.424974636524, 'lng': -3.684107212216363,  ...

# %%
starbucks = decoded[0].get("items")
type(starbucks)
# Out:
# list

# %%
type(starbucks[0])
# Out:
# dict

# %%
starbucks[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4b9a5902f964a520edad35e3',
#   'name': 'Starbucks',
#   'contact': {},
#   'location': {'address': 'C. del Conde de Peñalver, 10',
#    'crossStreet': 'C. Hermosilla',
#    'lat': 40.426066801136066,
#    'lng': -3.6756167469058876,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 40.426066801136066,
#      'lng': -3.6756167469058876}],
#    'distance': 497,
#    'postalCode': '28006',
#    'cc': 'ES',
#    'city': 'Madrid',
#    'state': 'Madrid',
#    'country': 'España',
#    'formattedAddress': ['C. del Conde de Peñalver, 10 (C. Hermosilla)',
#     '28006 Madrid Madrid',
#     'España']},
#   'categories': [{'id': '4bf58dd8d48988d1e0931735',
#     'name': 'Coffee Shop',
#     'pluralName': 'Coffee Shops',
#     'shortName': 'Coffee Shop',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#      'suffix': '.png'},
#     'primary': True}],
#   'verified': True,
#   'stats': {'tipCount': 0,
#    'usersCount': 0,
#    'checkinsCount': 0,
#    'visitsCount': 0},
#   'beenHere': {'count': 0,
#    'lastCheckinExpiredAt': 0,
#    'marked': False,
#    'unconfirmedCount': 0},
#   'photos': {'count': 0, 'groups': []},
#   'hereNow': {'count': 0, 'summary': 'Nobody here', 'groups': []}},
#  'referralId': 'e-0-4b9a5902f964a520edad35e3-0'}

# %%
starbucks[0].keys()
# Out:
# dict_keys(['reasons', 'venue', 'referralId'])

# %%
#saltos que damos dentro del diccionario para llegar al valor
map_name = ["venue","name"]
lat = ["venue", "location","lat"]
long = ["venue","location","lng"]

# %%
list_rest = []
for dict_elem in starbucks:
    list_test = {}
    list_test["name"] = getFromDict(dict_elem,map_name)
    list_test["latitud"] = getFromDict(dict_elem,lat)
    list_test["longitud"] = getFromDict(dict_elem,long)
    list_rest.append(list_test)

# %%
dataframefinal = pd.DataFrame(list_rest)
dataframefinal.head()
# Out:
#         name    latitud  longitud
# 0  Starbucks  40.426067 -3.675617
# 1  Starbucks  40.432968 -3.683220
# 2  Starbucks  40.433564 -3.686829
# 3  Starbucks  40.424975 -3.684107
# 4  Starbucks  40.425760 -3.691782

# %% [raw]
# Creamos el dataframe con los datos obtenidos

# %%
starbucks = dataframefinal.to_csv("./data/starbucks.csv")

# %%
gdf = gpd.GeoDataFrame(dataframefinal, geometry=gpd.points_from_xy(dataframefinal.longitud, dataframefinal.latitud))
print(f'Tipo: {type(gdf)}')
gdf.head()
# Out:
# Tipo: <class 'geopandas.geodataframe.GeoDataFrame'>
#         name    latitud  longitud                   geometry
# 0  Starbucks  40.426067 -3.675617  POINT (-3.67562 40.42607)
# 1  Starbucks  40.432968 -3.683220  POINT (-3.68322 40.43297)
# 2  Starbucks  40.433564 -3.686829  POINT (-3.68683 40.43356)
# 3  Starbucks  40.424975 -3.684107  POINT (-3.68411 40.42497)
# 4  Starbucks  40.425760 -3.691782  POINT (-3.69178 40.42576)

# %% [markdown]
# ###  Mapa

# %%
inicial_lat = 40.42955
inicial_long = -3.6793
type(inicial_lat)
# Out:
# float

# %%
madrid.get("coordinates")
print(madrid.get("coordinates"))
initial_long = madrid.get("coordinates")[0]
initial_lat = madrid.get("coordinates")[1]
initial_lat
# Out:
# [-3.6793, 40.42955]
# 40.42955

# %%
map_1 = folium.Map(location = [initial_lat,initial_long], zoom_start = 15)

# %%
create_marker(gdf,map_1)

# %%
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
